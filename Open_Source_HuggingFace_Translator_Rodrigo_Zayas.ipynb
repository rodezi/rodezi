# %% [markdown]
# <a href="https://colab.research.google.com/github/rodezi/rodezi/blob/main/Open_Source_HuggingFace_Translator_Rodrigo_Zayas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers

# %% [markdown]
# MarianMTModel cargara un modelo de traduccion

# %%
from transformers import MarianMTModel, MarianTokenizer

model_name = "Helsinki-NLP/opus-mt-en-es"

tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
text = ["Hello, this is part of my first projects in my professional portfolio. Welcome! "]
tokens = tokenizer(text, return_tensors='pt', padding=True, truncation=True)

# %% [markdown]
# Se genera la traducion y decodificamos los tokens.

# %%
traduccion_tokens = model.generate(**tokens)
produccion_texto = tokenizer.batch_decode(traduccion_tokens, skip_special_tokens=True)

# %%
for i,t in zip (text,produccion_texto):
  print(f"Ingles: {i}")
  print(f"Español: {t}")
# Out:
# Ingles: Hello, this is part of my first projects in my professional portfolio. Welcome!
# Español: Hola, esto es parte de mis primeros proyectos en mi portafolio profesional. ¡Bienvenido!
